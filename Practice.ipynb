# %% [markdown]
# NOTEBOOK

# %%
print('Hello words')
# Out:
# Hello words

# %%
import pandas as pd

# %%
import os
os.listdir(r"C:\Users\Dell\Internship Python ML")
# Out:
# ['basics.ipynb',
#  'first program.py',
#  'Practice.ipynb',
#  'real_estate_db.csv',
#  'real_estate_db.csv.zip',
#  'second..py',
#  'tempCodeRunnerFile.py']

# %%
df = pd.read_csv(r"c:\\Users\\DELL\\Internship Python ML",encoding="latin1")

# %%
import os
os.getcwd()
# Out:
# 'c:\\Users\\DELL\\Internship Python ML'

# %%
os.listdir()
# Out:
# ['basics.ipynb',
#  'first program.py',
#  'Practice.ipynb',
#  'real_estate_db.csv',
#  'second..py',
#  'tempCodeRunnerFile.py']

# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\DELL\Desktop\real_estate_db.csv",
                 encoding="latin1")

df.head()
# Out:
#       UID  BLOCKID  SUMLEVEL  COUNTYID  STATEID   state state_ab         city  \
# 0  220336      NaN       140        16        2  Alaska       AK     Unalaska
# 1  220342      NaN       140        20        2  Alaska       AK  Eagle River
# 2  220343      NaN       140        20        2  Alaska       AK         Jber
# 3  220345      NaN       140        20        2  Alaska       AK    Anchorage
# 4  220347      NaN       140        20        2  Alaska       AK    Anchorage
#
#              place  type  ... female_age_mean  female_age_median  \
# 0    Unalaska City  City  ...        32.78177           31.91667
# 1        Anchorage  City  ...        38.97956           39.66667
# 2        Anchorage  City  ...        22.20427           23.16667
# 3  Point Mackenzie  City  ...        37.00750           34.00000
# 4        Anchorage  City  ...        34.96611           31.75000
#
#    female_age_stdev  female_age_sample_weight  female_age_samples  pct_own  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39030 entries, 0 to 39029
# Data columns (total 80 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   UID                          39030 non-null  int64
#  1   BLOCKID                      0 non-null      float64
#  2   SUMLEVEL                     39030 non-null  int64
#  3   COUNTYID                     39030 non-null  int64
#  4   STATEID                      39030 non-null  int64
#  5   state                        39030 non-null  object
#  6   state_ab                     39030 non-null  object
#  7   city                         39030 non-null  object
#  8   place                        39030 non-null  object
#  9   type                         39030 non-null  object
#  10  primary                      39030 non-null  object
#  11  zip_code                     39030 non-null  int64
#  12  area_code                    39030 non-null  int64
# ...

# %%
df.describe(include='all')
# Out:
#                   UID  BLOCKID  SUMLEVEL      COUNTYID       STATEID  \
# count    39030.000000      0.0   39030.0  39030.000000  39030.000000
# unique            NaN      NaN       NaN           NaN           NaN
# top               NaN      NaN       NaN           NaN           NaN
# freq              NaN      NaN       NaN           NaN           NaN
# mean    257389.898847      NaN     140.0     85.665693     28.337023
# std      21380.595101      NaN       0.0     98.624203     16.457552
# min     220336.000000      NaN     140.0      1.000000      1.000000
# 25%     238817.250000      NaN     140.0     29.000000     13.000000
# 50%     257380.500000      NaN     140.0     63.000000     28.000000
# 75%     275970.750000      NaN     140.0    109.000000     42.000000
# max     294334.000000      NaN     140.0    840.000000     72.000000
#
#              state state_ab      city          place   type  ...  \
# count        39030    39030     39030          39030  39030  ...
# ...

# %%
df.isnull().sum()
# Out:
# UID                0
# BLOCKID        39030
# SUMLEVEL           0
# COUNTYID           0
# STATEID            0
#                ...
# pct_own          390
# married          275
# married_snp      275
# separated        275
# divorced         275
# Length: 80, dtype: int64

# %%
df['pop'].mean()
# Out:
# np.float64(4331.384678452472)

# %%
df['pop'].median()
# Out:
# 4065.0

# %%
df['pop'].mode()
# Out:
# 0    0
# Name: pop, dtype: int64

# %%
df['pop'].std()
# Out:
# 2155.2023884361756

# %%
df['pop'].var()
# Out:
# 4644897.335120996

# %%
df['pop'].quantile([0.25,.5,.75])
# Out:
# 0.25    2899.0
# 0.50    4065.0
# 0.75    5442.0
# Name: pop, dtype: float64

# %%
df['pop'].hist()
# Out:
# <Axes: >

# %%
import seaborn as sns

sns.kdeplot(df['pop'])
# Out:
# <Axes: xlabel='pop', ylabel='Density'>

# %%
df['state'].value_counts()
# Out:
# state
# California              4193
# Texas                   2767
# New York                2565
# Florida                 2289
# Pennsylvania            1735
# Illinois                1593
# Ohio                    1538
# Michigan                1463
# North Carolina          1167
# Georgia                 1078
# New Jersey              1009
# Virginia                1006
# Washington               806
# Indiana                  802
# Arizona                  798
# Tennessee                792
# Massachusetts            777
# Maryland                 764
# Wisconsin                732
# Missouri                 732
# Minnesota                699
# Colorado                 668
# Alabama                  612
# Louisiana                608
# Kentucky                 577
# South Carolina           561
# Oklahoma                 552
# Puerto Rico              489
# Oregon                   454
# Connecticut              445
# Kansas                   440
# Iowa                     415
# ...

# %%
df.corr(numeric_only=True)
# Out:
#                   UID  BLOCKID  SUMLEVEL  COUNTYID   STATEID  zip_code  \
# UID          1.000000      NaN       NaN  0.262793  0.976741 -0.226358
# BLOCKID           NaN      NaN       NaN       NaN       NaN       NaN
# SUMLEVEL          NaN      NaN       NaN       NaN       NaN       NaN
# COUNTYID     0.262793      NaN       NaN  1.000000  0.224276  0.034973
# STATEID      0.976741      NaN       NaN  0.224276  1.000000 -0.265258
# ...               ...      ...       ...       ...       ...       ...
# pct_own      0.070306      NaN       NaN -0.001070  0.068407 -0.067898
# married      0.040333      NaN       NaN -0.015853  0.024639  0.031060
# married_snp -0.038978      NaN       NaN  0.035130 -0.033785  0.015877
# separated    0.017849      NaN       NaN  0.064160  0.029272 -0.052255
# divorced     0.011845      NaN       NaN  0.048415  0.017777  0.046124
#
#              area_code       lat       lng     ALand  ...  female_age_mean  \
# ...

# %%
sns.heatmap(df.corr(numeric_only=True),cmap="coolwarm")
# Out:
# <Axes: >
